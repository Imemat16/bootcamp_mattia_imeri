# %%
import numpy as np

# Create a large array
large_array = np.arange(1_000_000)

print("--- Standard Python Loop ---")
# Out:
# --- Standard Python Loop ---

# %%
# %%time
# Standard loop: multiply every number by 2
loop_result = [x * 2 for x in large_array]
# Out:
# CPU times: total: 93.8 ms
# Wall time: 86.6 ms

# %%
# %%time
# Vectorized execution: multiply array by 2 directly
vectorized_result = large_array * 2
# Out:
# CPU times: total: 0 ns
# Wall time: 6.52 ms

# %%
# Load the CSV
df = pd.read_csv('../data/raw/starter_data.csv')

# Inspect the structure
print("--- DataFrame Info ---")
df.info()

# View the first few rows
print("\n--- First 5 Rows ---")
display(df.head())
# Out:
# --- DataFrame Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  10 non-null     str
#  1   value     10 non-null     int64
#  2   date      10 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 372.0 bytes
#
# --- First 5 Rows ---
#   category  value        date
# 0        A     10  2025-08-01
# 1        B     15  2025-08-02
# 2        A     12  2025-08-03
# 3        B     18  2025-08-04
# 4        C     25  2025-08-05

# %%
# Calculate describe() for numeric columns
summary_stats = df.describe()
display(summary_stats)

# Perform groupby() aggregation by category (e.g., getting the average)
category_summary = df.groupby('category').mean(numeric_only=True)
display(category_summary)
# Out:
#            value
# count  10.000000
# mean   17.600000
# std     7.381659
# min    10.000000
# 25%    12.250000
# 50%    14.500000
# 75%    23.250000
# max    30.000000
#               value
# category
# A         11.500000
# B         15.666667
# C         27.666667

# %%
df
# Out:
#   category  value        date
# 0        A     10  2025-08-01
# 1        B     15  2025-08-02
# 2        A     12  2025-08-03
# 3        B     18  2025-08-04
# 4        C     25  2025-08-05
# 5        C     30  2025-08-06
# 6        A     11  2025-08-07
# 7        B     14  2025-08-08
# 8        C     28  2025-08-09
# 9        A     13  2025-08-10

# %%
import matplotlib.pyplot as plt

# Save summary stats to processed folder
category_summary.to_csv('../data/processed/summary.csv')
print("Summary saved to data/processed/summary.csv")

# Bonus: Create and save a basic plot
plt.figure(figsize=(6, 4))
df.groupby('category')['value'].mean().plot(kind='bar', color='skyblue')
plt.title('Average Price by Category')
plt.ylabel('Average Price')

# Save the plot BEFORE calling plt.show()
plt.savefig('../data/processed/category_plot.png')
plt.show()
# Out:
# Summary saved to data/processed/summary.csv

# %%
import sys
import os

# Add the parent folder to Python's path so it can find the src folder
sys.path.append(os.path.abspath('..'))

# Import your new function
from src.utils import get_summary_stats

# Test it out
desc, grouped = get_summary_stats(df)
print("Function worked! Here is the grouped data:")
display(grouped)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 11
#       7 # Import your new function
#       8 from src.utils import get_summary_stats
#       9
#      10 # Test it out
# ---> 11 desc, grouped = get_summary_stats(df)
#      12 print("Function worked! Here is the grouped data:")
#      13 display(grouped)
#
# File ~\bootcamp_mattia_imeri\homework\homework03\src\utils.py:6, in get_summary_stats(df)
#       4 """Returns the describe summary and a grouped mean summary."""
#       5 describe_df = df.describe()
# ----> 6 group_df = df.groupby('category').mean()
#       7 return describe_df, group_df
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\internals\managers.py:1667, in BlockManager.grouped_reduce(self, func)
#    1665             result_blocks = extend_blocks(applied, result_blocks)
#    1666     else:
# -> 1667         applied = blk.apply(func)
#    1668         result_blocks = extend_blocks(applied, result_blocks)
#    1670 if len(result_blocks) == 0:
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\groupby\ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~\miniconda3\envs\fe-course\Lib\site-packages\pandas\core\arrays\base.py:2808, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2794 if isinstance(self.dtype, StringDtype):
#    2795     # StringArray
#    2796     if op.how in [
#    2797         "prod",
#    2798         "mean",
#    (...)   2806         "kurt",
#    2807     ]:
# -> 2808         raise TypeError(
#    2809             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2810         )
#    2811     if op.how not in ["any", "all"]:
#    2812         # Fail early to avoid conversion to object
#    2813         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'
