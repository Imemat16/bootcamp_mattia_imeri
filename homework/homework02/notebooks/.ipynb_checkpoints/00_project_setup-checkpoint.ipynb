# %% [markdown]
# # Environment & Config Check

# %%
from dotenv import load_dotenv
import os
import numpy as np

# Load secrets
load_dotenv(dotenv_path="../.env") # Paths adjust since you are in notebooks/

# Print if API_KEY exists
if os.getenv("API_KEY"):
    print("API_KEY exists!")

# Run a small array operation
arr = np.array([10, 20, 30])
print("My array multiplied by 2:", arr * 2)
# Out:
# My array multiplied by 2: [20 40 60]
